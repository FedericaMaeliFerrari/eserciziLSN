# %% [markdown]
# ### Exercise 04.2
# Riprende quanto fatto dall'esercizio precedente, con l'aggiunta però del calcolo della media a blocchi. La simulazione dunque, eseguita con il metodo di Restart, è stata suddivisa in $1000$ blocchi,ogni blocco composto da $1000$ step. All'inizio di ogni blocco la velocità e le coordinate al tempo $t-dt$ sono state corrette per ottenere la temperatura desiderata, pari a $1.1$ in unità ridotte per lo stato liquido.
# Oltre al grafico dell'andamento della temperatura nel tempo ho riportato anche i grafici dell'Energia Cinetica, dell'Energia potenziale e dell'Energia totale del sistema (data come somma dell'energia cinetica e dell'energia potenziale).
# Come si può osservare meglio dall'ultimo grafico (in cui sono riportati gli andamenti di tutti i parametri contemoraneamente), il sistema è praticamente stazionario, in quanto tutti i valori sono stabili (a parte il momento iniziale).
# Questo perchè prima di prendere le misure di queste grandezze il sistema è stato fatto evolvere nel tempo (per $10000$ step), facendogli raggiungere l'equilibrio.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

temp=np.loadtxt("output.Temp.0")
ekin=np.loadtxt("output.Ekin.0")
epot=np.loadtxt("output.Epot.0")
etot=np.loadtxt("output.Etot.0")


plt.errorbar(temp[:,0],temp[:,2],temp[:,3])
plt.xlabel("Nblocchi")
plt.ylabel("T")
plt.title("Stima di T")
plt.grid(True)
plt.show()

plt.errorbar(ekin[:,0],ekin[:,2],ekin[:,3])
plt.xlabel("Nblocchi")
plt.ylabel("Ekin")
plt.title("Stima di Ekin")
plt.grid(True)
plt.show()

plt.errorbar(epot[:,0],epot[:,2],epot[:,3])
plt.xlabel("Nblocchi")
plt.ylabel("Epot")
plt.title("Stima di Epot")
plt.grid(True)
plt.show()

plt.errorbar(etot[:,0],etot[:,2],etot[:,3])
plt.xlabel("Nblocchi")
plt.ylabel("Etot")
plt.title("Stima di Etot")
plt.grid(True)
plt.show()
